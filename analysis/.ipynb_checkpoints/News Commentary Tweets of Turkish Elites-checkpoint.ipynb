# %%
import pandas as pd
import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *
# %matplotlib inline

# %%
df = pd.read_csv('data/TR-headlines.csv',usecols=['newsdate','title','twcount'],parse_dates=[0])

# %%
df
# Out:
#         newsdate  twcount                                              title
# 0     2015-01-09        6       IŞİD’den sonra El Kaide de katliamı üstlendi
# 1     2015-01-09        3                           TEOG sonuçları açıklandı
# 2     2015-01-09        7  Kaplan’ın karikatüre “zulüm” nitelemesi gündem...
# 3     2015-01-09        4  Taraf: “AK Parti listeleri AK Saray’da hazırla...
# 4     2015-01-09       25   Hollande: “Bu fanatiklerin İslam ile ilgisi yok”
# 5     2015-01-09        5  Saldırılar Fransa’da idam cezasını gündeme get...
# 6     2015-01-09        6  Batı Avrupalı liderler pazar günü Paris’e gidiyor
# 7     2015-01-09        8  Arınç: “Lezbiyenler, biseksüeller ve translar ...
# 8     2015-01-09        5                 Fransa’da kuyumcu soygunu korkuttu
# 9     2015-01-09       10  İstanbul’da AVM’ye bombalı saldırı son anda ön...
# 10    2015-01-09       37  Fransa’daki saldırılar “İslam ve terör” tartış...
# 11    2015-01-09       48  Eş zamanlı operasyonlar: 3 terörist ve 4 rehin...
# 12    2015-01-09       11      DHKP-C: “Sultanahmet’i yanlışlıkla üstlendik”
# 13    2015-01-09       14  Press TV: “IŞİD Paris saldırısını üstlendi; AB...
# 14    2015-01-09        4  CHP’li Aksünger: “Barış Güler’in dai­resinin k...
# 15    2015-01-09        5  Fransız İçişleri’nden Eyfel açıklaması: “Yanlı...
# 16    2015-01-09        6  AK Partili üyelerin “Yüce Divan’a ret” gerekçe...
# 17    2015-01-09        5  Yalçın: “Erdoğan’a Başbakanlık yolunu seks kas...
# 18    2015-01-09       26           Paris’te bir markette yeni rehine eylemi
# 19    2015-01-09        5  AYM’den askeri casusluk davasında hak ihlali k...
# 20    2015-01-09        8  Kazaz: “Paris saldırısının amacı İslamofobiyi ...
# 21    2015-01-09        4                    Bekaroğlu’nun refleksi gündemde
# 22    2015-01-09        7      Taksim Meydanı’nda Charlie Hebdo’yu yırttılar
# 23    2015-01-09       53  Charlie Hebdo saldırganları kıstırıldı; rehine...
# 24    2015-01-09       14                              Cemal Süreya anılıyor
# 25    2015-01-09        6             Paris’in kuzeyinde ev ev saldırgan avı
# 26    2015-01-09        5           ABD’de eski valiye rüşvetten 2 yıl hapis
# 27    2015-01-09        8  LeMan’a uyarı: “Charlie Hebdo saldırısından de...
# 28    2015-01-09        9    Paris’teki 3′lü cinayetin üzerinden 2 yıl geçti
# 29    2015-01-09        5  Eyfel Kulesi milli yas kapsamında karanlığa gö...
# ...          ...      ...                                                ...
# 12482 2013-01-16        3                 Guardiola Bayern Münih ile anlaştı
# 12483 2013-01-16       16               Yılmaz Erdoğan yeni film ile dönüyor
# 12484 2013-01-16        7                   Facebook yeni özelliğini duyurdu
# 12485 2013-01-16       23             Mehmet Ali Birand hastaneye kaldırıldı
# 12486 2013-01-16        5           Öcalan’dan anayasa için iki isim önerisi
# 12487 2013-01-16        5                        Deniz Feneri davası başladı
# 12488 2013-01-16       35             Ünlü ressam Doğançay hayatını kaybetti
# 12489 2013-01-16       37                 3 PKK’lının cenazesi Diyarbakır’da
# 12490 2013-01-16       32                            “Teke Tek”te orta oyunu
# 12491 2013-01-15        5                                 Kocaeli’de katliam
# 12492 2013-01-15       20                           Nazım Hikmet 111 yaşında
# 12493 2013-01-15       33                        Erdoğan’dan sağduyu çağrısı
# 12494 2013-01-15       13       Ahmet Altan’ın koltuğu Oral Çalışlar’ın oldu
# 12495 2013-01-15        7          Cumhuriyet Rektör Laçiner’den özür diledi
# 12496 2013-01-15       21      Ali Bulaç: “Kadın çalıştığı için öldürülüyor”
# 12497 2013-01-15       16             Rasim Ozan’a Galatasaraylılardan tepki
# 12498 2013-01-15        9                     Paris cinayetinde yeni gelişme
# 12499 2013-01-15       11            Kardeş Öcalan: “Televizyonu o istemedi”
# 12500 2013-01-15       13                   Hülyalı Odeabank reklamına tepki
# 12501 2013-01-14       19                      Metin Kaçan’ın cesedi bulundu
# 12502 2013-01-14       19          Arınç’tan cenazelerde provakasyon uyarısı
# 12503 2013-01-14       25                      TÜBİTAK evrimi kökünden çözdü
# 12504 2013-01-14       22                    CHP’de yeni Hüseyin Aygün krizi
# 12505 2013-01-14       15    PKK’lıların cenazeleri Diyarbakır’a getirilecek
# 12506 2013-01-14        7                    Samanyolu muhabirlerine saldırı
# 12507 2013-01-14       10  Paris suikastı ile ilgili bir iddia da “Balıkç...
# 12508 2013-01-14       11       Bahçeli’den İmralı’ya karşı Silivri ziyareti
# 12509 2013-01-14       14                              CHP’den Çin çıkarması
# 12510 2013-01-14       24                           1979 İran’ına ödül yağdı
# 12511 2013-01-14       30            Sağlık Bakanlığı’ndan Refiye açıklaması
#
# [12512 rows x 3 columns]

# %%
daily = df.groupby('newsdate').sum()

# %%
daily.plot()

# %%
data = Data([Scatter(x=daily.index,y=daily.twcount)])

# %%
twc = df.groupby('newsdate').apply(lambda t: t[t.twcount == t.twcount.max()])

# %%
titles = twc[twc.newsdate.isin(daily.sort('twcount',ascending=False).head(11).index.values)]
titles = titles.sort('twcount',ascending=False)
titles = titles.reset_index(drop=True)
titles = pd.merge(titles,daily,left_on='newsdate',right_index=True)
titles.rename(columns={'twcount_x': 'twcount', 'twcount_y': 'twdaily'}, inplace=True)
titles
# Out:
#      newsdate  twcount                                             title  \
# 0  2013-09-30      345                       İşte demokratikleşme paketi
# 1  2013-05-31      284                  Olaylar Taksim çevresine sıçradı
# 2  2013-06-01      283                         Başbakan’dan ilk açıklama
# 3  2013-06-11      266                        Taksim savaş alanına döndü
# 4  2013-06-16      260                 Başbakan’dan Kazlıçeşme mesajları
# 5  2013-06-02      233                                Medyaya büyük öfke
# 6  2014-03-21      225                       Twitter’a erişim engellendi
# 7  2013-12-18      167                  “Büyük Rüşvet” Türkiye’yi sarstı
# 8  2013-12-25      167   İstifa eden Bayraktar: “Başbakan istifa etmeli”
# 9  2014-05-14      147  Bilanço ağırlaşıyor: “Ölü sayısı 205′e yükseldi”
# 10 2014-08-10      146                  Erdoğan: “Seçimin kaybedeni yok”
#
#     twdaily
# 0       940
# 1      1872
# 2      1343
# 3      1508
# 4       947
# 5      1342
# 6      1157
# 7       944
# 8      1105
# 9      1217
# 10      984

# %%
def annotator(r):
    if r['newsdate'] == pd.to_datetime('2013-09-30'):
        y = r['twdaily']-10
    elif r['newsdate'] == pd.to_datetime('2013-06-02'):
        y = r['twdaily']-10
    else:
        y=r['twdaily']+40
    return Annotation(x=r['newsdate'], y=y, xref='x', yref='y', text=r['title'], showarrow=False)

# %%
annotations = Annotations(map(annotator,titles.to_dict(orient='records')))
layout = Layout(title="News Commentary Tweets of Turkish Elites (Jan 2013 - Jan 2015)",
                annotations=annotations,yaxis=YAxis(title='Daily tweet counts'))
fig = Figure(data=data, layout=layout)

# %%
py.iplot(fig,filename="News Commentary Tweets of Turkish Elites")
